# %%
# !pip install mljar-mercury
# Out:
# ^C

# %%
k = input("hello")
print("yea" + k)
# Out:
# helload
# yeaad
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached Markdown-3.3.6-py3-none-any.whl (97 kB)
# ...
#   Created wheel for mljar-mercury: filename=mljar_mercury-1.1.6-py3-none-any.whl size=4582614 sha256=f6d634b929bfde9425dbf0f696cf33e78002e2273368e90a8be070d21c242891
#   Stored in directory: c:\users\dev thapa\appdata\local\pip\cache\wheels\cc\46\ed\e0729ab6378165accb4efc00af3376fb588ced2437ae681eaa
# Successfully built mljar-mercury
# ...
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.0.5
#     Uninstalling traitlets-5.0.5:
#       Successfully uninstalled traitlets-5.0.5
#   Attempting uninstall: asgiref
#     Found existing installation: asgiref 3.2.10
# ...
